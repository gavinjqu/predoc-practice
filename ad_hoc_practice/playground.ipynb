# %%
import numpy as np

data2 = [[1, 2, 3, 4], [5, 6, 7.0, 8]]
arr2 = np.array(data2)
print(f"shape and data type of arr2: {arr2.shape} & {arr2.dtype}")
# Out:
# shape and data type of arr2: (2, 4) & float64
