# %% [markdown]
# # Task 1: CPS Data Exploration & Cleaning
#
# **Time target:** 2 hours
# **Date attempted:**
# **Actual time:**
#
# See `instructions.md` for full task description and questions.

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams.update({
    'figure.figsize': (10, 6),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'font.size': 12,
})

# Use the existing CPS data or place your own in data/
DATA_PATH = '../../data/clean_nov25pub.csv'
# DATA_PATH = 'data/your_file.csv'

# %% [markdown]
# ## 2. Data Loading & Initial Assessment
#
# **Q1-Q4:** Load the data, identify unit of observation, assess missing values and data types.

# %%
# Load data

# %%
# Assess structure, types, missingness

# %% [markdown]
# ## 3. Data Cleaning & Preparation
#
# Document every cleaning decision.

# %%
# Cleaning steps

# %% [markdown]
# ## 4. Summary Statistics
#
# **Q5-Q7:** Compute summary stats, breakdowns by demographics, hours worked distribution.

# %%
# Summary statistics table

# %%
# Employment rates by age, education, sex

# %%
# Hours worked distribution (histogram)

# %% [markdown]
# ## 5. Exploratory Analysis & Visualization
#
# **Q8-Q10:** Earnings by education, age-earnings relationship, one interesting pattern.

# %%
# Earnings by education level

# %%
# Age vs earnings

# %%
# Your interesting pattern

# %% [markdown]
# ## 6. Written Interpretation
#
# ### Data Description
#
# [Describe the dataset: source, sample size, key variables, time period.]
#
# ### Key Findings
#
# [Present 3-4 key findings with specific numbers from your analysis.]
#
# ### Limitations
#
# [What are the limitations of this descriptive analysis? What would you investigate further?]
