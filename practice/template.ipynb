# %% [markdown]
# # [Task Title]
#
# **Time target:** X hours
# **Date attempted:**
# **Actual time:**

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Plot style
plt.rcParams.update({
    'figure.figsize': (10, 6),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'font.size': 12,
})

# Data paths
DATA_DIR = 'data/'

# %% [markdown]
# ## 2. Data Loading & Initial Assessment

# %%
# Load data
# df = pd.read_csv(DATA_DIR + 'filename.csv')

# First look
# df.info()
# df.describe()
# df.head()

# %% [markdown]
# ## 3. Data Cleaning & Preparation
#
# Document every cleaning decision with a brief justification.

# %%
# Cleaning steps here

# %% [markdown]
# ## 4. Analysis

# %%
# Core analytical work here

# %% [markdown]
# ## 5. Visualization
#
# Every figure should have: title, axis labels, legend (if needed), clean layout.

# %%
# Figures here

# %% [markdown]
# ## 6. Results Summary

# %%
# Formatted tables here

# %% [markdown]
# ## 7. Written Interpretation
#
# ### What did you do?
#
# [Describe your approach: data sources, cleaning decisions, analytical method, and why you chose it.]
#
# ### What did you find?
#
# [Present key results with statistical interpretation: coefficient magnitudes, significance, confidence intervals.]
#
# ### What does it mean economically?
#
# [Translate statistical results into economic meaning. Discuss limitations, threats to identification, and what additional analysis could strengthen the conclusions.]
