# %% [markdown]
# # Task 2: Wage Regression & Interpretation
#
# **Time target:** 3 hours
# **Date attempted:**
# **Actual time:**
#
# See `instructions.md` for full task description and questions.

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

plt.rcParams.update({
    'figure.figsize': (10, 6),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'font.size': 12,
})

DATA_PATH = '../../data/clean_nov25pub.csv'
# DATA_PATH = 'data/your_file.csv'

# %% [markdown]
# ## 2. Sample Construction
#
# **Q1-Q3:** Load data, construct analysis sample (employed, ages 25-64, positive earnings), document restrictions.

# %%
# Load and construct sample

# %%
# Create education variable

# %%
# Sample size tracking

# %% [markdown]
# ## 3. Descriptive Analysis
#
# **Q4-Q6:** Mean earnings by education, log earnings vs education scatter, distribution of log earnings.

# %%
# Earnings by education table

# %%
# Log earnings vs education scatter/binscatter

# %%
# Distribution of log earnings

# %% [markdown]
# ## 4. Regression Analysis
#
# **Q7-Q10:** Mincerian wage equation, add controls, by-sex estimation, regression table.

# %%
# Model 1: Baseline Mincerian equation
# log(earnings) = B0 + B1*education + B2*experience + B3*experience^2 + e

# %%
# Model 2: Add controls (sex, race, region)

# %%
# Model 3: By sex

# %%
# Publication-quality regression table
# Columns: baseline, with controls, men, women

# %% [markdown]
# ## 5. Identification Discussion
#
# **Q11-Q12:** Discuss identification concerns and potential strategies.
#
# ### Key identification concern
#
# [What prevents us from interpreting the education coefficient as causal?]
#
# ### Sources of omitted variable bias
#
# [Name at least two.]
#
# ### Potential identification strategy
#
# [Describe one approach to estimate the causal effect and its key assumption.]

# %% [markdown]
# ## 6. Research Memo
#
# ### Research Question
#
# [What are the returns to education in terms of earnings?]
#
# ### Data and Methods
#
# [Describe data source, sample construction, and estimation approach.]
#
# ### Key Findings
#
# [Report specific coefficient estimates with interpretation.]
#
# ### Limitations
#
# [Discuss threats to causal interpretation and data limitations.]
